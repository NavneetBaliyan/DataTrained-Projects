# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
df_avocado=pd.read_csv("avocado.csv")
df_avocado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# 5             5.0  22-11-2015          1.26      55979.78  1184.27   48067.99
# 6             6.0  15-11-2015          0.99      83453.76  1368.92   73672.72
# 7             7.0  08-11-2015          0.98     109428.33   703.75  101815.36
# 8             8.0  01-11-2015          1.02      99811.42  1022.15   87315.57
# 9             9.0  25-10-2015          1.07      74338.76   842.40   64757.44
# 10           10.0  18-10-2015          1.12      84843.44   924.86   75595.85
# ...

# %%
df_avocado.keys()
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df_avocado.shape
# Out:
# (16468, 14)

# %%
df_avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df_avocado.dtypes
# Out:
# Unnamed: 0      float64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
df_avocado.isnull
# Out:
# <bound method DataFrame.isnull of        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# 5             5.0  22-11-2015          1.26      55979.78  1184.27   48067.99
# 6             6.0  15-11-2015          0.99      83453.76  1368.92   73672.72
# 7             7.0  08-11-2015          0.98     109428.33   703.75  101815.36
# 8             8.0  01-11-2015          1.02      99811.42  1022.15   87315.57
# 9             9.0  25-10-2015          1.07      74338.76   842.40   64757.44
# 10           10.0  18-10-2015          1.12      84843.44   924.86   75595.85
# ...

# %%
df_avocado.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %%
df_avocado1=df_avocado.dropna(axis=0,how='any')

# %%
df_avocado1
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 0            0.0  27-12-2015          1.33      64236.62     1036.74
# 1            1.0  20-12-2015          1.35      54876.98      674.28
# 2            2.0  13-12-2015          0.93     118220.22      794.70
# 3            3.0  06-12-2015          1.08      78992.15     1132.00
# 4            4.0  29-11-2015          1.28      51039.60      941.48
# 5            5.0  22-11-2015          1.26      55979.78     1184.27
# 6            6.0  15-11-2015          0.99      83453.76     1368.92
# 7            7.0  08-11-2015          0.98     109428.33      703.75
# 8            8.0  01-11-2015          1.02      99811.42     1022.15
# 9            9.0  25-10-2015          1.07      74338.76      842.40
# 10          10.0  18-10-2015          1.12      84843.44      924.86
# 11          11.0  11-10-2015          1.28      64489.17     1582.03
# 12          12.0  04-10-2015          1.31      61007.10     2268.32
# ...

# %%
df_avocado1.shape
# Out:
# (1517, 14)

# %%
df_avocado1.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df_avocado1.isnull())

# %%
sns.pairplot(df_avocado1)

# %%
df_avocado1['AveragePrice'].plot.box()

# %%
df_avocado1['Total Volume'].plot.box()

# %%
df_avocado1['Total Bags'].plot.box()

# %%
df_avocado1.plot(kind='box',subplots=True,layout=(2,7))
# Out:
# Unnamed: 0         AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# AveragePrice    AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# Total Volume    AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# 4046            AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# 4225            AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# 4770            AxesSubplot(0.692073,0.536818;0.0945122x0.343182)
# Total Bags      AxesSubplot(0.805488,0.536818;0.0945122x0.343182)
# Small Bags            AxesSubplot(0.125,0.125;0.0945122x0.343182)
# Large Bags         AxesSubplot(0.238415,0.125;0.0945122x0.343182)
# XLarge Bags        AxesSubplot(0.351829,0.125;0.0945122x0.343182)
# year               AxesSubplot(0.465244,0.125;0.0945122x0.343182)
# dtype: object

# %%
df_avocado1.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# dtype: float64

# %%
df_avocado1.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.075531      0.091934  0.092013  0.093566
# AveragePrice   -0.075531      1.000000     -0.140470 -0.190096 -0.092084
# Total Volume    0.091934     -0.140470      1.000000  0.985568  0.987154
# 4046            0.092013     -0.190096      0.985568  1.000000  0.951952
# 4225            0.093566     -0.092084      0.987154  0.951952  1.000000
# 4770            0.075647     -0.100567      0.934347  0.898570  0.927757
# Total Bags      0.081007     -0.111597      0.967689  0.930395  0.951779
# Small Bags      0.083485     -0.097682      0.960642  0.922278  0.943988
# Large Bags      0.065364     -0.177480      0.910226  0.884229  0.900496
# XLarge Bags    -0.050993     -0.048284      0.521717  0.474063  0.504718
# year           -0.012854      0.178683     -0.004189 -0.040439 -0.007254
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
sns.heatmap(df_avocado1.corr())

# %%
df_avocado2=df_avocado1.drop('region',axis=1)

# %%
df_avocado2
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 0            0.0  27-12-2015          1.33      64236.62     1036.74
# 1            1.0  20-12-2015          1.35      54876.98      674.28
# 2            2.0  13-12-2015          0.93     118220.22      794.70
# 3            3.0  06-12-2015          1.08      78992.15     1132.00
# 4            4.0  29-11-2015          1.28      51039.60      941.48
# 5            5.0  22-11-2015          1.26      55979.78     1184.27
# 6            6.0  15-11-2015          0.99      83453.76     1368.92
# 7            7.0  08-11-2015          0.98     109428.33      703.75
# 8            8.0  01-11-2015          1.02      99811.42     1022.15
# 9            9.0  25-10-2015          1.07      74338.76      842.40
# 10          10.0  18-10-2015          1.12      84843.44      924.86
# 11          11.0  11-10-2015          1.28      64489.17     1582.03
# 12          12.0  04-10-2015          1.31      61007.10     2268.32
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df_avocado2['type']=le.fit_transform(df_avocado2['type'])
df_avocado2.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  type    year
# 0   48.16     8696.87     8603.62       93.25          0.0     0  2015.0
# 1   58.33     9505.56     9408.07       97.49          0.0     0  2015.0
# 2  130.50     8145.35     8042.21      103.14          0.0     0  2015.0
# 3   72.58     5811.16     5677.40      133.76          0.0     0  2015.0
# 4   75.78     6183.95     5986.26      197.69          0.0     0  2015.0

# %%
df_avocado2
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 0            0.0  27-12-2015          1.33      64236.62     1036.74
# 1            1.0  20-12-2015          1.35      54876.98      674.28
# 2            2.0  13-12-2015          0.93     118220.22      794.70
# 3            3.0  06-12-2015          1.08      78992.15     1132.00
# 4            4.0  29-11-2015          1.28      51039.60      941.48
# 5            5.0  22-11-2015          1.26      55979.78     1184.27
# 6            6.0  15-11-2015          0.99      83453.76     1368.92
# 7            7.0  08-11-2015          0.98     109428.33      703.75
# 8            8.0  01-11-2015          1.02      99811.42     1022.15
# 9            9.0  25-10-2015          1.07      74338.76      842.40
# 10          10.0  18-10-2015          1.12      84843.44      924.86
# 11          11.0  11-10-2015          1.28      64489.17     1582.03
# 12          12.0  04-10-2015          1.31      61007.10     2268.32
# ...

# %%
df_avocado2.shape
# Out:
# (1517, 13)

# %%
df_avocado1.shape
# Out:
# (1517, 14)

# %%
df_avocado3=df_avocado2.drop('Date',axis=1)

# %%
df_avocado3
# Out:
#       Unnamed: 0  AveragePrice  Total Volume        4046        4225  \
# 0            0.0          1.33      64236.62     1036.74    54454.85
# 1            1.0          1.35      54876.98      674.28    44638.81
# 2            2.0          0.93     118220.22      794.70   109149.67
# 3            3.0          1.08      78992.15     1132.00    71976.41
# 4            4.0          1.28      51039.60      941.48    43838.39
# 5            5.0          1.26      55979.78     1184.27    48067.99
# 6            6.0          0.99      83453.76     1368.92    73672.72
# 7            7.0          0.98     109428.33      703.75   101815.36
# 8            8.0          1.02      99811.42     1022.15    87315.57
# 9            9.0          1.07      74338.76      842.40    64757.44
# 10          10.0          1.12      84843.44      924.86    75595.85
# 11          11.0          1.28      64489.17     1582.03    52677.92
# 12          12.0          1.31      61007.10     2268.32    49880.67
# ...

# %%
df_avocado3.shape
# Out:
# (1517, 12)

# %%
df_avocado3.fillna(0)
# Out:
#       Unnamed: 0  AveragePrice  Total Volume        4046        4225  \
# 0            0.0          1.33      64236.62     1036.74    54454.85
# 1            1.0          1.35      54876.98      674.28    44638.81
# 2            2.0          0.93     118220.22      794.70   109149.67
# 3            3.0          1.08      78992.15     1132.00    71976.41
# 4            4.0          1.28      51039.60      941.48    43838.39
# 5            5.0          1.26      55979.78     1184.27    48067.99
# 6            6.0          0.99      83453.76     1368.92    73672.72
# 7            7.0          0.98     109428.33      703.75   101815.36
# 8            8.0          1.02      99811.42     1022.15    87315.57
# 9            9.0          1.07      74338.76      842.40    64757.44
# 10          10.0          1.12      84843.44      924.86    75595.85
# 11          11.0          1.28      64489.17     1582.03    52677.92
# 12          12.0          1.31      61007.10     2268.32    49880.67
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_avocado3
# Out:
#       Unnamed: 0  AveragePrice  Total Volume        4046        4225  \
# 0            0.0          1.33      64236.62     1036.74    54454.85
# 1            1.0          1.35      54876.98      674.28    44638.81
# 2            2.0          0.93     118220.22      794.70   109149.67
# 3            3.0          1.08      78992.15     1132.00    71976.41
# 4            4.0          1.28      51039.60      941.48    43838.39
# 5            5.0          1.26      55979.78     1184.27    48067.99
# 6            6.0          0.99      83453.76     1368.92    73672.72
# 7            7.0          0.98     109428.33      703.75   101815.36
# 8            8.0          1.02      99811.42     1022.15    87315.57
# 9            9.0          1.07      74338.76      842.40    64757.44
# 10          10.0          1.12      84843.44      924.86    75595.85
# 11          11.0          1.28      64489.17     1582.03    52677.92
# 12          12.0          1.31      61007.10     2268.32    49880.67
# ...

# %%
import numpy as np
for col in df_avocado3.columns:
    if df_avocado3.skew().loc[col]>0.55:
        df_avocado3[col]=np.log1p(df_avocado3[col])

# %%
df_avocado3.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Total Bags      0.695502
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# type            0.000000
# year            1.828332
# dtype: float64

# %%
x=df_avocado3.drop("AveragePrice",axis=1)
y=df_avocado3["AveragePrice"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(30,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=20,random_state=r_state)
    lr=linear_model.LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corresponding to random state:",r_state,"is",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print()
print("max r2_score corresponding to",final_r_state,"is",max_r_score)
# Out:
# r2_score corresponding to random state: 30 is 0.42348543762808954
# r2_score corresponding to random state: 31 is 0.3895222777609705
# r2_score corresponding to random state: 32 is 0.21313151126921215
# r2_score corresponding to random state: 33 is 0.297577122094669
# r2_score corresponding to random state: 34 is 0.48925567429192673
# r2_score corresponding to random state: 35 is -0.13467428348875
# r2_score corresponding to random state: 36 is 0.35604308521243044
# r2_score corresponding to random state: 37 is 0.46819685715907
# r2_score corresponding to random state: 38 is 0.6171116150116032
# r2_score corresponding to random state: 39 is 0.6202819037021163
# r2_score corresponding to random state: 40 is 0.4895102476784372
# r2_score corresponding to random state: 41 is 0.07226808221256509
# r2_score corresponding to random state: 42 is -0.13541208291495166
# r2_score corresponding to random state: 43 is 0.26191637568235404
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=25,random_state=40)

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
y_pred=lr.predict(x_test)
r2_scr=r2_score(y_test,y_pred)
print("r2score is:",r2_scr)
# Out:
# r2score is: 0.4950251257412486

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.11341894861649965
# MSE: 0.022097377313643442
# RMSE: 0.14865186616266693

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=dtr.predict(x_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.092
# MSE: 0.023304000000000002
# RMSE: 0.15265647709809108

# %%
from sklearn.ensemble import RandomForestRegressor
rdr = RandomForestRegressor()
rdr.fit(x_train,y_train)
pred=rdr.predict(x_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.06467999999999999
# MSE: 0.008874759999999995
# RMSE: 0.09420594461073035

# %%
from sklearn.externals import joblib
joblib.dump(rdr,"avacadodataset")
# Out:
# ['avacadodataset']
