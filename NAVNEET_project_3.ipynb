# %%
import pandas as pd
import numpy as np

# %%
df_abalone=pd.read_csv("abalone (1).data")
df_abalone
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# 5     F  0.530  0.415  0.150  0.7775  0.2370  0.1415  0.3300  20
# 6     F  0.545  0.425  0.125  0.7680  0.2940  0.1495  0.2600  16
# 7     M  0.475  0.370  0.125  0.5095  0.2165  0.1125  0.1650   9
# 8     F  0.550  0.440  0.150  0.8945  0.3145  0.1510  0.3200  19
# 9     F  0.525  0.380  0.140  0.6065  0.1940  0.1475  0.2100  14
# 10    M  0.430  0.350  0.110  0.4060  0.1675  0.0810  0.1350  10
# 11    M  0.490  0.380  0.135  0.5415  0.2175  0.0950  0.1900  11
# 12    F  0.535  0.405  0.145  0.6845  0.2725  0.1710  0.2050  10
# ...

# %%
df_abalone.keys()
# Out:
# Index(['M', '0.455', '0.365', '0.095', '0.514', '0.2245', '0.101', '0.15',
#        '15'],
#       dtype='object')

# %%
df_abalone.isnull()
# Out:
#           M  0.455  0.365  0.095  0.514  0.2245  0.101   0.15     15
# 0     False  False  False  False  False   False  False  False  False
# 1     False  False  False  False  False   False  False  False  False
# 2     False  False  False  False  False   False  False  False  False
# 3     False  False  False  False  False   False  False  False  False
# 4     False  False  False  False  False   False  False  False  False
# 5     False  False  False  False  False   False  False  False  False
# 6     False  False  False  False  False   False  False  False  False
# 7     False  False  False  False  False   False  False  False  False
# 8     False  False  False  False  False   False  False  False  False
# 9     False  False  False  False  False   False  False  False  False
# 10    False  False  False  False  False   False  False  False  False
# 11    False  False  False  False  False   False  False  False  False
# 12    False  False  False  False  False   False  False  False  False
# ...

# %%
df_abalone.isnull().sum()
# Out:
# M         0
# 0.455     0
# 0.365     0
# 0.095     0
# 0.514     0
# 0.2245    0
# 0.101     0
# 0.15      0
# 15        0
# dtype: int64

# %%
df_abalone.describe()
# Out:
#              0.455        0.365        0.095        0.514      0.2245  \
# count  4176.000000  4176.000000  4176.000000  4176.000000  4176.00000
# mean      0.524009     0.407892     0.139527     0.828818     0.35940
# std       0.120103     0.099250     0.041826     0.490424     0.22198
# min       0.075000     0.055000     0.000000     0.002000     0.00100
# 25%       0.450000     0.350000     0.115000     0.441500     0.18600
# 50%       0.545000     0.425000     0.140000     0.799750     0.33600
# 75%       0.615000     0.480000     0.165000     1.153250     0.50200
# max       0.815000     0.650000     1.130000     2.825500     1.48800
#
#              0.101         0.15           15
# count  4176.000000  4176.000000  4176.000000
# mean      0.180613     0.238852     9.932471
# std       0.109620     0.139213     3.223601
# min       0.000500     0.001500     1.000000
# 25%       0.093375     0.130000     8.000000
# 50%       0.171000     0.234000     9.000000
# ...

# %%
df_abalone['0.455'].plot.box()

# %%
df_abalone['0.095'].plot.box()

# %%
df_abalone['0.2245'].plot.box()

# %%
df_abalone.plot(kind='box',subplots=True,layout=(1,8))
# Out:
# 0.455        AxesSubplot(0.125,0.125;0.0824468x0.755)
# 0.365     AxesSubplot(0.223936,0.125;0.0824468x0.755)
# 0.095     AxesSubplot(0.322872,0.125;0.0824468x0.755)
# 0.514     AxesSubplot(0.421809,0.125;0.0824468x0.755)
# 0.2245    AxesSubplot(0.520745,0.125;0.0824468x0.755)
# 0.101     AxesSubplot(0.619681,0.125;0.0824468x0.755)
# 0.15      AxesSubplot(0.718617,0.125;0.0824468x0.755)
# 15        AxesSubplot(0.817553,0.125;0.0824468x0.755)
# dtype: object

# %%
df_abalone.corr()
# Out:
#            0.455     0.365     0.095     0.514    0.2245     0.101      0.15  \
# 0.455   1.000000  0.986813  0.827552  0.925255  0.897905  0.903010  0.897697
# 0.365   0.986813  1.000000  0.833705  0.925452  0.893159  0.899726  0.905328
# 0.095   0.827552  0.833705  1.000000  0.819209  0.774957  0.798293  0.817326
# 0.514   0.925255  0.925452  0.819209  1.000000  0.969403  0.966372  0.955351
# 0.2245  0.897905  0.893159  0.774957  0.969403  1.000000  0.931956  0.882606
# 0.101   0.903010  0.899726  0.798293  0.966372  0.931956  1.000000  0.907647
# 0.15    0.897697  0.905328  0.817326  0.955351  0.882606  0.907647  1.000000
# 15      0.557123  0.575005  0.558109  0.540818  0.421256  0.504274  0.628031
#
#               15
# 0.455   0.557123
# 0.365   0.575005
# 0.095   0.558109
# 0.514   0.540818
# 0.2245  0.421256
# 0.101   0.504274
# 0.15    0.628031
# 15      1.000000

# %%
import seaborn as sns
sns.heatmap(df_abalone.corr())

# %%
df_abalone.skew()
# Out:
# 0.455    -0.640240
# 0.365    -0.609457
# 0.095     3.129241
# 0.514     0.530576
# 0.2245    0.718724
# 0.101     0.591463
# 0.15      0.620547
# 15        1.115157
# dtype: float64

# %%
df_abalone
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# 5     F  0.530  0.415  0.150  0.7775  0.2370  0.1415  0.3300  20
# 6     F  0.545  0.425  0.125  0.7680  0.2940  0.1495  0.2600  16
# 7     M  0.475  0.370  0.125  0.5095  0.2165  0.1125  0.1650   9
# 8     F  0.550  0.440  0.150  0.8945  0.3145  0.1510  0.3200  19
# 9     F  0.525  0.380  0.140  0.6065  0.1940  0.1475  0.2100  14
# 10    M  0.430  0.350  0.110  0.4060  0.1675  0.0810  0.1350  10
# 11    M  0.490  0.380  0.135  0.5415  0.2175  0.0950  0.1900  11
# 12    F  0.535  0.405  0.145  0.6845  0.2725  0.1710  0.2050  10
# ...

# %%
Genders = {"M": 0, "F": 1, "I":2 }
data = [df_abalone]

for dataset in data:
    dataset['M'] = dataset['M'].map(Genders)

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
for col in df_abalone.columns:
    if df_abalone.skew().loc[col]>0.55:
        df_abalone[col]=np.log1p(df_abalone[col])

# %%
df_abalone.skew()
# Out:
# M         0.082624
# 0.455    -0.640240
# 0.365    -0.609457
# 0.095     1.099478
# 0.514     0.530576
# 0.2245    0.306070
# 0.101     0.375234
# 0.15      0.314939
# 15       -0.061065
# dtype: float64

# %%
sns.pairplot(df_abalone)

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_abalone["0.455"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e6645e02e8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e6646238d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e664623748>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e6645417b8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e664541128>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_abalone["0.365"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e6644d6518>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e66469bba8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e66469b128>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e66469bfd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e6660625c0>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_abalone["0.095"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e66444b2b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e6660ba630>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e6660adb00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e6660bacc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e6660bada0>],
#  'means': []}

# %%
plt.boxplot(df_abalone["0.514"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e664518048>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e66611fb00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e66611f048>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e66611ff28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e66612b518>],
#  'means': []}

# %%
plt.boxplot(df_abalone["0.2245"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x248072ebb70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x248072ebeb8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x248072eb780>],
#  'medians': [<matplotlib.lines.Line2D at 0x248072f6940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x248072f6c88>],
#  'means': []}

# %%
plt.boxplot(df_abalone["0.101"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x248073512e8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x248073519e8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24807342eb8>],
#  'medians': [<matplotlib.lines.Line2D at 0x24807351e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2480735c400>],
#  'means': []}

# %%
from scipy.stats import zscore
zscore=abs(zscore(df_abalone))
print(df_abalone.shape)
df_abalone1=df_abalone.loc[(zscore<3).all(axis=1)]
print(df_abalone1.shape)
# Out:
# (4176, 9)
# (4101, 9)

# %%
x=df_abalone1.iloc[:,0:5]

# %%
Y=df_abalone1.iloc[:,-3]

# %%
x.shape
# Out:
# (4101, 5)

# %%
Y.shape
# Out:
# (4101,)

# %%
y=Y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (4101, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(30,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=20,random_state=r_state)
    lr=linear_model.LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corresponding to random state:",r_state,"is",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print()
print("max r2_score corresponding to",final_r_state,"is",max_r_score)
# Out:
# r2_score corresponding to random state: 30 is 0.9385208027938354
# r2_score corresponding to random state: 31 is 0.855979133070861
# r2_score corresponding to random state: 32 is 0.9197814741778763
# r2_score corresponding to random state: 33 is 0.9583966917179768
# r2_score corresponding to random state: 34 is 0.8288984237764332
# r2_score corresponding to random state: 35 is 0.9146963420940657
# r2_score corresponding to random state: 36 is 0.9336114462705114
# r2_score corresponding to random state: 37 is 0.960524176815544
# r2_score corresponding to random state: 38 is 0.9043080582319089
# r2_score corresponding to random state: 39 is 0.9473613071266749
# r2_score corresponding to random state: 40 is 0.9240895107274557
# r2_score corresponding to random state: 41 is 0.9112126814311912
# r2_score corresponding to random state: 42 is 0.9608063195482631
# r2_score corresponding to random state: 43 is 0.962985458744789
# ...

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2").mean()
# Out:
# 0.9387638271499485

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np
print("r2_score is :",r2_score(y_test,y_pred))
print("RMSE is :",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score is : 0.9455329655705451
# RMSE is : 0.019520335861936144

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=8,random_state=r_state)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
from sklearn.externals import joblib
joblib.dump(lr,'lr_salarydatasets.pk5')
# Out:
# ['lr_salarydatasets.pk5']
