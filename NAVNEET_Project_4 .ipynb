# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_bikeshare=pd.read_csv("day.csv")
df_bikeshare
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 9         10  2011-01-10       1   0     1        0        1           1
# 10        11  2011-01-11       1   0     1        0        2           1
# 11        12  2011-01-12       1   0     1        0        3           1
# ...

# %%
df_bikeshare.shape
# Out:
# (731, 16)

# %%
df_bikeshare.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df_bikeshare.isnull()
# Out:
#      instant  dteday  season     yr   mnth  holiday  weekday  workingday  \
# 0      False   False   False  False  False    False    False       False
# 1      False   False   False  False  False    False    False       False
# 2      False   False   False  False  False    False    False       False
# 3      False   False   False  False  False    False    False       False
# 4      False   False   False  False  False    False    False       False
# 5      False   False   False  False  False    False    False       False
# 6      False   False   False  False  False    False    False       False
# 7      False   False   False  False  False    False    False       False
# 8      False   False   False  False  False    False    False       False
# 9      False   False   False  False  False    False    False       False
# 10     False   False   False  False  False    False    False       False
# 11     False   False   False  False  False    False    False       False
# ...

# %%
sns.heatmap(df_bikeshare.isnull())

# %%
df_bikeshare.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df_bikeshare.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
sns.pairplot(df_bikeshare)

# %%
df_bikeshare.corr()
# Out:
#              instant    season        yr      mnth   holiday   weekday  \
# instant     1.000000  0.412224  0.866025  0.496702  0.016145 -0.000016
# season      0.412224  1.000000 -0.001844  0.831440 -0.010537 -0.003080
# yr          0.866025 -0.001844  1.000000 -0.001792  0.007954 -0.005461
# mnth        0.496702  0.831440 -0.001792  1.000000  0.019191  0.009509
# holiday     0.016145 -0.010537  0.007954  0.019191  1.000000 -0.101960
# weekday    -0.000016 -0.003080 -0.005461  0.009509 -0.101960  1.000000
# workingday -0.004337  0.012485 -0.002013 -0.005901 -0.253023  0.035790
# weathersit -0.021477  0.019211 -0.048727  0.043528 -0.034627  0.031087
# temp        0.150580  0.334315  0.047604  0.220205 -0.028556 -0.000170
# atemp       0.152638  0.342876  0.046106  0.227459 -0.032507 -0.007537
# hum         0.016375  0.205445 -0.110651  0.222204 -0.015937 -0.052232
# windspeed  -0.112620 -0.229046 -0.011817 -0.207502  0.006292  0.014282
# ...

# %%
df_bikeshare.skew()
# Out:
# instant       0.000000
# season       -0.000384
# yr           -0.002742
# mnth         -0.008149
# holiday       5.654224
# weekday       0.002742
# workingday   -0.793147
# weathersit    0.957385
# temp         -0.054521
# atemp        -0.131088
# hum          -0.069783
# windspeed     0.677345
# casual        1.266454
# registered    0.043659
# cnt          -0.047353
# dtype: float64

# %%
import seaborn as sns
sns.heatmap(df_bikeshare.corr())

# %%
df_bikeshare.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
#checking the outliers
import matplotlib.pyplot as plt
plt.boxplot(df_bikeshare["holiday"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bdfcfb6f60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bdfcfc0940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bdfcfb6e10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bdfcfc0fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bdfcfc0f60>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_bikeshare["hum"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bdfd017e10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bdfd022518>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bdfd017a58>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bdfd022ba8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bdfd022ef0>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_bikeshare["windspeed"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bdfd07e828>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bdfd07eeb8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bdfd07e4a8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bdfd088588>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bdfd0888d0>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_bikeshare["casual"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bdfd0d8f98>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bdfd0e6978>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bdfd0d8e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bdfd0e6da0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bdfd0ef390>],
#  'means': []}

# %%
sns.countplot(x="weathersit",data=df_bikeshare)

# %%
sns.countplot(x="workingday",data=df_bikeshare)

# %%
sns.countplot(df_bikeshare["workingday"])

# %%
df_bikeshare1=df_bikeshare.drop("dteday",axis=1)

# %%
from scipy.stats import zscore
zscore=abs(zscore(df_bikeshare1))
print(df_bikeshare1.shape)
df_bikeshare2=df_bikeshare1.loc[(zscore<3).all(axis=1)]
print(df_bikeshare2.shape)
# Out:
# (731, 15)
# (700, 15)

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
for col in df_bikeshare2.columns:
    if df_bikeshare2.skew().loc[col]>0.55:
        df_bikeshare2[col]=np.log1p(df_bikeshare2[col])

# %%
df_bikeshare2.skew()
# Out:
# instant       0.014307
# season       -0.014917
# yr            0.017180
# mnth         -0.013480
# holiday       0.000000
# weekday      -0.018876
# workingday   -0.935263
# weathersit    0.736478
# temp         -0.056952
# atemp        -0.131745
# hum           0.074956
# windspeed     0.470711
# casual       -0.963078
# registered    0.056654
# cnt          -0.051049
# dtype: float64

# %%
import seaborn as sns
sns.pairplot(df_bikeshare2)

# %%
x=df_bikeshare2.iloc[:,0:15]

# %%
x.shape
# Out:
# (700, 15)

# %%
y=df_bikeshare2.iloc[:,-1]

# %%
y.shape
# Out:
# (700,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(30,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=20,random_state=r_state)
    lr=linear_model.LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corresponding to random state:",r_state,"is",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print()
print("max r2_score corresponding to",final_r_state,"is",max_r_score)
# Out:
# r2_score corresponding to random state: 30 is 1.0
# r2_score corresponding to random state: 31 is 1.0
# r2_score corresponding to random state: 32 is 1.0
# r2_score corresponding to random state: 33 is 1.0
# r2_score corresponding to random state: 34 is 1.0
# r2_score corresponding to random state: 35 is 1.0
# r2_score corresponding to random state: 36 is 1.0
# r2_score corresponding to random state: 37 is 1.0
# r2_score corresponding to random state: 38 is 1.0
# r2_score corresponding to random state: 39 is 1.0
# r2_score corresponding to random state: 40 is 1.0
# r2_score corresponding to random state: 41 is 1.0
# r2_score corresponding to random state: 42 is 1.0
# r2_score corresponding to random state: 43 is 1.0
# r2_score corresponding to random state: 44 is 1.0
# r2_score corresponding to random state: 45 is 1.0
# r2_score corresponding to random state: 46 is 1.0
# r2_score corresponding to random state: 47 is 1.0
# r2_score corresponding to random state: 48 is 1.0
# ...

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2").mean()
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np
print("r2_score is :",r2_score(y_test,y_pred))
print("RMSE is :",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score is : 1.0
# RMSE is : 6.390777945196167e-13

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=20,random_state=r_state)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
from sklearn.externals import joblib
joblib.dump(lr,"lr_Bikeshareday")
# Out:
# ['lr_Bikeshareday']
